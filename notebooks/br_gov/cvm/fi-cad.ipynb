# %% [markdown]
# # Fundos de Investimento: Informação Cadastral
#
# Dados cadastrais de fundos de investimento estruturados e não estruturados (ICVM 555), tais como: CNPJ, data de registro e situação do fundo.
#
# O conjunto de dados disponibiliza:
#
# - Fundos de Investimento - Conjunto Completo: As informações cadastrais referentes ao último dia útil.
# - Fundos de Investimento ICVM 555 - Histórico: O histórico de alteração de informações cadastrais (atualização diária).
#
# A atualização dos arquivos ocorre de terça a sábado, às 08:00h, com a posição cadastral dos fundos até as 23:59h do dia anterior.

# %%
import pandas as pd
import requests
from io import BytesIO

# %%
def get_cad_fi() -> pd.DataFrame:
    url = "https://dados.cvm.gov.br/dados/FI/CAD/DADOS/cad_fi.csv"
    data = requests.get(url).content
    df = pd.read_csv(BytesIO(data), sep=";", encoding="ISO-8859-1")
    return df

df = get_cad_fi()
df
# Out:
# /tmp/ipykernel_31039/666181234.py:4: DtypeWarning: Columns (14,17,18,20,22,24,27,37,38,39,40) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(BytesIO(data), sep=";", encoding="ISO-8859-1")
#       TP_FUNDO          CNPJ_FUNDO  \
# 0       FACFIF  00.000.684/0001-21
# 1       FACFIF  00.000.731/0001-37
# 2       FACFIF  00.000.732/0001-81
# 3       FACFIF  00.000.740/0001-28
# 4       FACFIF  00.000.749/0001-39
# ...        ...                 ...
# 79466  FUNCINE  31.674.280/0001-47
# 79467  FUNCINE  32.222.962/0001-81
# 79468  FUNCINE  48.879.897/0001-00
# 79469  FUNCINE  52.714.528/0001-26
# 79470  FUNCINE  52.715.603/0001-73
#
#                                             DENOM_SOCIAL      DT_REG  \
# 0      DEUTSCHE BANK FDO APLIC QUOTAS FDO INV FINANCE...  2003-04-30
# 1      ITAMARITI CASH FUNDO APLICACAO QUOTAS FDOS INV...  2003-04-30
# 2      FUNDO APLIC. QUOTAS DE F.I. SANTANDER CURTO PRAZO  2003-04-30
# 3      FUNDO DE APLIC EM QUOTAS DE FUNDOS DE INV BMC ...  2003-04-30
# 4      BALANCE FUNDO APLICACAO QUOTAS FUNDO INVESTIME...  2003-04-30
# ...                                                  ...         ...
# 79466  MEDIA VENTURE ESG INCENTIVADO - FUNDO DE FINAN...  2018-10-26
# 79467  Fundo de Financiamento da Indústria Cinematogr...  2018-12-20
# 79468  FUNDO DE  FINANCIAMENTO DA INDÚSTRIA CINEMATOG...  2022-12-13
# 79469  INVESTIMAGE 4 - FUNDO DE FINANCIAMENTO DA INDÚ...  2023-10-30
# 79470  INVESTIMAGE 5 - FUNDO DE FINANCIAMENTO DA INDÚ...  2023-10-30
#
#          DT_CONST    CD_CVM   DT_CANCEL                      SIT  DT_INI_SIT  \
# 0      1994-12-20      19.0  2000-08-01                CANCELADA  2000-08-01
# 1      1994-05-18   40681.0  1996-01-26                CANCELADA  1996-01-26
# 2      1994-05-24      27.0  1999-09-03                CANCELADA  1999-09-03
# 3      1994-05-23   40690.0  1996-06-10                CANCELADA  1996-06-10
# 4      1994-05-12      35.0  2000-06-26                CANCELADA  2000-06-26
# ...           ...       ...         ...                      ...         ...
# 79466  2018-09-13  418001.0  2023-07-21                CANCELADA  2023-07-21
# 79467  2018-11-14  418002.0  2021-10-29                CANCELADA  2021-10-29
# 79468  2022-12-01  422001.0         NaN     FASE PRÉ-OPERACIONAL  2022-12-13
# 79469  2023-10-17  423001.0         NaN  EM FUNCIONAMENTO NORMAL  2023-12-28
# 79470  2023-10-02  423002.0         NaN     FASE PRÉ-OPERACIONAL  2023-10-30
#
#       DT_INI_ATIV  ...     CPF_CNPJ_GESTOR  \
# 0             NaN  ...                 NaN
# 1             NaN  ...                 NaN
# 2             NaN  ...                 NaN
# 3             NaN  ...                 NaN
# 4             NaN  ...                 NaN
# ...           ...  ...                 ...
# 79466         NaN  ...  09.544.103/0001-97
# 79467         NaN  ...  09.544.103/0001-97
# 79468  2022-12-13  ...  18.190.296/0001-16
# 79469  2023-12-28  ...  09.544.103/0001-97
# 79470  2023-10-30  ...  09.544.103/0001-97
#
#                                              GESTOR        CNPJ_AUDITOR  \
# 0                                               NaN                 NaN
# 1                                               NaN                 NaN
# 2                                               NaN                 NaN
# 3                                               NaN                 NaN
# 4                                               NaN                 NaN
# ...                                             ...                 ...
# 79466  INVESTIMAGE ADMINISTRADORA DE RECURSOS LTDA.  16.549.480/0001-84
# 79467  INVESTIMAGE ADMINISTRADORA DE RECURSOS LTDA.  57.755.217/0001-29
# 79468                   CEDRO ASSET MANAGEMENT LTDA  19.280.834/0001-26
# 79469  INVESTIMAGE ADMINISTRADORA DE RECURSOS LTDA.  19.280.834/0001-26
# 79470  INVESTIMAGE ADMINISTRADORA DE RECURSOS LTDA.  19.280.834/0001-26
#
#                                         AUDITOR    CNPJ_CUSTODIANTE  \
# 0                                           NaN                 NaN
# 1                                           NaN                 NaN
# 2                                           NaN                 NaN
# 3                                           NaN                 NaN
# 4                                           NaN                 NaN
# ...                                         ...                 ...
# 79466  RSM BRASIL AUDITORES INDEPENDENTES LTDA.  16.695.922/0001-09
# 79467        KPMG AUDITORES INDEPENDENTES LTDA.  15.489.568/0001-95
# 79468    NEXT AUDITORES INDEPENDENTES S/S LTDA.  16.695.922/0001-09
# 79469    NEXT AUDITORES INDEPENDENTES S/S LTDA.  16.695.922/0001-09
# 79470    NEXT AUDITORES INDEPENDENTES S/S LTDA.  16.695.922/0001-09
#
#                                              CUSTODIANTE CNPJ_CONTROLADOR  \
# 0                                                    NaN              NaN
# 1                                                    NaN              NaN
# 2                                                    NaN              NaN
# 3                                                    NaN              NaN
# 4                                                    NaN              NaN
# ...                                                  ...              ...
# 79466  ID CORRETORA DE TITULOS E VALORES MOBILIARIOS ...              NaN
# 79467                      INTRA INVESTIMENTOS DTVM LTDA              NaN
# 79468  ID CORRETORA DE TITULOS E VALORES MOBILIARIOS ...              NaN
# 79469  ID CORRETORA DE TITULOS E VALORES MOBILIARIOS ...              NaN
# 79470  ID CORRETORA DE TITULOS E VALORES MOBILIARIOS ...              NaN
#
#       CONTROLADOR INVEST_CEMPR_EXTER CLASSE_ANBIMA
# 0             NaN                NaN           NaN
# 1             NaN                NaN           NaN
# 2             NaN                NaN           NaN
# 3             NaN                NaN           NaN
# 4             NaN                NaN           NaN
# ...           ...                ...           ...
# 79466         NaN                NaN           NaN
# 79467         NaN                NaN           NaN
# 79468         NaN                NaN           NaN
# 79469         NaN                NaN           NaN
# 79470         NaN                NaN           NaN
#
# [79471 rows x 41 columns]

# %%
df2 = df.groupby("CNPJ_FUNDO").last().reset_index(drop=True)
len(df2)
# Out:
# 70057

# %%
from zipfile import ZipFile


def get_fi_cad_historical():
    url = "https://dados.cvm.gov.br/dados/FI/CAD/DADOS/cad_fi_hist.zip"
    data = requests.get(url).content
    with ZipFile(BytesIO(data)) as z:
        for f in z.namelist():
            if f.endswith(".csv"):
                with z.open(f) as zf:
                    df = pd.read_csv(zf, sep=";", encoding="ISO-8859-1")
                    df.Name = f[:-4]
                    col_names = {}
                    for col in df.columns:
                        col_names[col] = col.lower()
                    df.rename(columns=col_names, inplace=True)
                    yield df


hist = list(get_fi_cad_historical())
for df in hist:
    print(df.Name, len(df))
# Out:
# cad_fi_hist_admin 74512
# cad_fi_hist_auditor 100466
# cad_fi_hist_classe 61029
# cad_fi_hist_condom 62227
# cad_fi_hist_controlador 70645
# cad_fi_hist_custodiante 71432
# cad_fi_hist_denom_comerc 74774
# cad_fi_hist_denom_social 110926
# cad_fi_hist_diretor_resp 155616
# cad_fi_hist_exclusivo 61893
# cad_fi_hist_exerc_social 443446
# cad_fi_hist_fic 63415
# cad_fi_hist_gestor 81411
# cad_fi_hist_publico_alvo 41840
# cad_fi_hist_rentab 58270
# cad_fi_hist_sit 123340
# cad_fi_hist_taxa_adm 77981
# cad_fi_hist_taxa_perfm 42015
# cad_fi_hist_trib_lprazo 55176

# %%
from pyportela.repositories.PostgresWarehouse import PostgresWarehouse
warehouse = PostgresWarehouse(f"postgresql://postgres:popo8160@localhost:5432/br_gov_cvm")

# %%
for df in hist:
    print(df.Name, warehouse.add_data(df, True))
# Out:
# cad_fi_hist_admin 512
# cad_fi_hist_auditor 466
# cad_fi_hist_classe 29
# cad_fi_hist_condom 227
# cad_fi_hist_controlador 645
# cad_fi_hist_custodiante 432
# cad_fi_hist_denom_comerc 774
# cad_fi_hist_denom_social 926
# cad_fi_hist_diretor_resp 616
# cad_fi_hist_exclusivo 893
# cad_fi_hist_exerc_social 446
# cad_fi_hist_fic 415
# cad_fi_hist_gestor 411
# cad_fi_hist_publico_alvo 840
# cad_fi_hist_rentab 270
# cad_fi_hist_sit 340
# cad_fi_hist_taxa_adm 981
# cad_fi_hist_taxa_perfm 15
# cad_fi_hist_trib_lprazo 176
